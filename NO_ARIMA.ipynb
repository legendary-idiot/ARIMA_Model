# %% [markdown]
# <a href="https://colab.research.google.com/github/legendary-idiot/ARIMA_Model/blob/main/NO_ARIMA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Install Prophet and Dependencies**

# %%
# !pip install prophet

# %%
import pandas as pd
from prophet import Prophet
from prophet.plot import plot_plotly, plot_components_plotly

# %% [markdown]
# # **2. Data Import and Visualize**

# %%
df = pd.read_csv('/content/Pollutant_Data/Pollutant Data.csv')
df.dropna(inplace= True)
df.reset_index(drop=True, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1095 non-null   object
#  1   SO2     1095 non-null   float64
#  2   NO      1095 non-null   float64
#  3   NO2     1095 non-null   float64
#  4   NOx     1095 non-null   float64
#  5   O3      1095 non-null   float64
#  6   PM2.5   1095 non-null   float64
#  7   PM10    1095 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 68.6+ KB

# %%
df.head()
# Out:
#        Date     SO2       NO      NO2       NOx       O3    PM2.5      PM10
# 0  1-Jan-21  2.0590  31.3940  19.0900   50.4840  11.7230  27.3530  112.4580
# 1  2-Jan-21  2.5045  38.0809  32.8662   72.0315  11.5146  51.8938  178.5706
# 2  3-Jan-21  2.9500  46.1920  56.5840  102.7760  11.3100  98.4525  283.5500
# 3  4-Jan-21  2.8667  35.8671  27.4246   58.8083  27.7379  71.7288  197.7121
# 4  5-Jan-21  2.9475  47.4900  29.2929   74.8042  22.7471  86.1671  195.8113

# %%
df.tail()
# Out:
#            Date     SO2       NO      NO2      NOx      O3     PM2.5      PM10
# 1090  27-Dec-23  7.4313  32.0225   8.9050  38.7013  2.5577  172.9479  233.7886
# 1091  28-Dec-23  5.4300  10.2100  17.9800  28.1900  2.5225  243.0800  311.2325
# 1092  29-Dec-23  5.1629  14.5946  10.6950  25.2896  2.5363  141.5100  228.3850
# 1093  30-Dec-23  4.8596   4.9267   8.9063  13.8329  2.5204   79.0046  150.1833
# 1094  31-Dec-23  4.6693  12.3886   9.1957  21.5843  2.5307   92.4479  147.1693

# %% [markdown]
# # **3. Select Data to Predict**

# %%
df=df[["Date","NO"]]
df.head()
# Out:
#        Date       NO
# 0  1-Jan-21  31.3940
# 1  2-Jan-21  38.0809
# 2  3-Jan-21  46.1920
# 3  4-Jan-21  35.8671
# 4  5-Jan-21  47.4900

# %% [markdown]
# **Change Column Names for FBProphet**

# %%
df.columns = ['ds','y']

# %% [markdown]
# **Convert Date Format to YY-MM-DD**

# %%
df['ds'] = pd.to_datetime(df['ds'])
df.tail()
# Out:
#              ds        y
# 1090 2023-12-27  32.0225
# 1091 2023-12-28  10.2100
# 1092 2023-12-29  14.5946
# 1093 2023-12-30   4.9267
# 1094 2023-12-31  12.3886

# %% [markdown]
# # **4. Start Making Predictions**

# %%
m = Prophet(daily_seasonality=True)
m.fit(df)

# %% [markdown]
# **Predictions for 1 Year (365 Days)**

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 1455 2024-12-26
# 1456 2024-12-27
# 1457 2024-12-28
# 1458 2024-12-29
# 1459 2024-12-30

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds       yhat  yhat_lower  yhat_upper
# 1455 2024-12-26 -16.296107  -30.784605   -1.935968
# 1456 2024-12-27 -17.151386  -31.723516   -3.006585
# 1457 2024-12-28 -16.793839  -30.810744   -1.764558
# 1458 2024-12-29 -17.137549  -31.511495   -2.756191
# 1459 2024-12-30 -15.528053  -30.043964   -1.120494

# %% [markdown]
# # **5. Plot the Predicted Data**

# %%
fig1 = m.plot(forecast)
fig2 = m.plot_components(forecast)

# %% [markdown]
# **Interactive Plot**

# %%
from prophet.plot import plot_plotly, plot_components_plotly

plot_plotly(m, forecast)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3a2855e7-e983-4a37-bac2-0e244d921816" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a2855e7-e983-4a37-bac2-0e244d921816")) {                    Plotly.newPlot(                        "3a2855e7-e983-4a37-bac2-0e244d921816",                        [{"marker":{"color":"black","size":4},"mode":"markers","name":"Actual","x":["2021-01-01T00:00:00","2021-01-02T00:00:00","2021-01-03T00:00:00","2021-01-04T00:00:00","2021-01-05T00:00:00","2021-01-06T00:00:00","2021-01-07T00:00:00","2021-01-08T00:00:00","2021-01-09T00:00:00","2021-01-10T00:00:00","2021-01-11T00:00:00","2021-01-12T00:00:00","2021-01-13T00:00:00","2021-01-14T00:00:00","2021-01-15T00:00:00","2021-01-16T00:00:00","2021-01-17T00:00:00","2021-01-18T00:00:00","2021-01-19T00:00:00","2021-01-20T00:00:00","2021-01-21T00:00:00","2021-01-22T00:00:00","2021-01-23T00:00:00","2021-01-24T00:00:00","2021-01-25T00:00:00","2021-01-26T00:00:00","2021-01-27T00:00:00","2021-01-28T00:00:00","2021-01-29T00:00:00","2021-01-30T00:00:00","2021-01-31T00:00:00","2021-02-01T00:00:00","2021-02-02T00:00:00","2021-02-03T00:00:00","2021-02-04T00:00:00","2021-02-05T00:00:00","2021-02-06T00:00:00","2021-02-07T00:00:00","2021-02-08T00:00:00","2021-02-09T00:00:00","2021-02-10T00:00:00","2021-02-11T00:00:00","2021-02-12T00:00:00","2021-02-13T00:00:00","2021-02-14T00:00:00","2021-02-15T00:00:00","2021-02-16T00:00:00","2021-02-17T00:00:00","2021-02-18T00:00:00","2021-02-19T00:00:00","2021-02-20T00:00:00","2021-02-21T00:00:00","2021-02-22T00:00:00","2021-02-23T00:00:00","2021-02-24T00:00:00","2021-02-25T00:00:00","2021-02-26T00:00:00","2021-02-27T00:00:00","2021-02-28T00:00:00","2021-03-01T00:00:00","2021-03-02T00:00:00","2021-03-03T00:00:00","2021-03-04T00:00:00","2021-03-05T00:00:00","2021-03-06T00:00:00","2021-03-07T00:00:00","2021-03-08T00:00:00","2021-03-09T00:00:00","2021-03-10T00:00:00","2021-03-11T00:00:00","2021-03-12T00:00:00","2021-03-13T00:00:00","2021-03-14T00:00:00","2021-03-15T00:00:00","2021-03-16T00:00:00","2021-03-17T00:00:00","2021-03-18T00:00:00","2021-03-19T00:00:00","2021-03-20T00:00:00","2021-03-21T00:00:00","2021-03-22T00:00:00","2021-03-23T00:00:00","2021-03-24T00:00:00","2021-03-25T00:00:00","2021-03-26T00:00:00","2021-03-27T00:00:00","2021-03-28T00:00:00","2021-03-29T00:00:00","2021-03-30T00:00:00","2021-03-31T00:00:00","2021-04-01T00:00:00","2021-04-02T00:00:00","2021-04-03T00:00:00","2021-04-04T00:00:00","2021-04-05T00:00:00","2021-04-06T00:00:00","2021-04-07T00:00:00","2021-04-08T00:00:00","2021-04-09T00:00:00","2021-04-10T00:00:00","2021-04-11T00:00:00","2021-04-12T00:00:00","2021-04-13T00:00:00","2021-04-14T00:00:00","2021-04-15T00:00:00","2021-04-16T00:00:00","2021-04-17T00:00:00","2021-04-18T00:00:00","2021-04-19T00:00:00","2021-04-20T00:00:00","2021-04-21T00:00:00","2021-04-22T00:00:00","2021-04-23T00:00:00","2021-04-24T00:00:00","2021-04-25T00:00:00","2021-04-26T00:00:00","2021-04-27T00:00:00","2021-04-28T00:00:00","2021-04-29T00:00:00","2021-04-30T00:00:00","2021-05-01T00:00:00","2021-05-02T00:00:00","2021-05-03T00:00:00","2021-05-04T00:00:00","2021-05-05T00:00:00","2021-05-06T00:00:00","2021-05-07T00:00:00","2021-05-08T00:00:00","2021-05-09T00:00:00","2021-05-10T00:00:00","2021-05-11T00:00:00","2021-05-12T00:00:00","2021-05-13T00:00:00","2021-05-14T00:00:00","2021-05-15T00:00:00","2021-05-16T00:00:00","2021-05-17T00:00:00","2021-05-18T00:00:00","2021-05-19T00:00:00","2021-05-20T00:00:00","2021-05-21T00:00:00","2021-05-22T00:00:00","2021-05-23T00:00:00","2021-05-24T00:00:00","2021-05-25T00:00:00","2021-05-26T00:00:00","2021-05-27T00:00:00","2021-05-28T00:00:00","2021-05-29T00:00:00","2021-05-30T00:00:00","2021-05-31T00:00:00","2021-06-01T00:00:00","2021-06-02T00:0 ...

# %% [markdown]
# # **6. Export the Predicted Data**

# %%
export = forecast[["ds", "yhat"]]
export.head()
# Out:
#           ds       yhat
# 0 2021-01-01  46.009957
# 1 2021-01-02  46.170012
# 2 2021-01-03  45.604828
# 3 2021-01-04  46.973461
# 4 2021-01-05  47.299010

# %%
export.to_csv('/content/Pollutant_Data/Predicted_NO.csv')
